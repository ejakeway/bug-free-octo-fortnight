# %%
# This is a heading.
* a bullet
* bullets are made using an asterisk and then a space

This is some text.
# Out:
#   File "<ipython-input-6-bb3c3086755d>", line 2
#     * a bullet
#              ^
# SyntaxError: invalid syntax

# %%
print("Eileen is struggling.")
# Out:
# Eileen is struggling.
